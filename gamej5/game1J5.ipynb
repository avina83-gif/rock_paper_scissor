# %% [markdown]
# جلسه پنجم که ما داریم بازی سنگ  و کاغذ قیچی میسازیم

# %%
gamefram=['سنگ','کاغذ ','قیچی']
print (type(gamefram))
for item in gamefram:
    print(item)
    #print(gamefram)

user=input("بین سنگ و کاغذ و قیچی یک را انتخاب کنید :")
computer='سنگ'

computer_point=0
your_point=0

if user=='سنگ' and computer=='کاغذ ':
    computer_point+=1
if user=='سنگ' and computer=='قیچی':
    your_point+=1    
if user=='کاغذ ' and computer=='سنگ':
    your_point+=1 
if user=='کاغذ ' and computer=='قیچی':
    computer_point+=1     
if user=='قیچی' and computer=='کاغذ ':
    your_point+=1 
if user=='قیچی' and computer=='سنگ':
    computer_point+=1
# Out:
# <class 'list'>
# سنگ
# کاغذ
# قیچی

# %%
import random

print(random.randint(0,100))
# Out:
# 58

# %%
import random
gamefram=['سنگ','کاغذ ','قیچی']

computer_point=0
your_point=0

gameroul=True

while(gameroul):
    randnum=random.randint(0,2)
    computer=gamefram[randnum]
    user=input("بین سنگ و کاغذ و قیچی یک را انتخاب کنید :")
    if user=='سنگ' and computer=='کاغذ ':
       computer_point+=1
    if user=='سنگ' and computer=='قیچی':
       your_point+=1    
    if user=='کاغذ ' and computer=='سنگ':
       your_point+=1 
    if user=='کاغذ ' and computer=='قیچی':
       computer_point+=1     
    if user=='قیچی' and computer=='کاغذ ':
       your_point+=1 
    if user=='قیچی' and computer=='سنگ':
       computer_point+=1 

    # print("YOU: ",your_point,' - ',user)
    # print("COM: ",computer_point,' - ',computer)   
    print("YOU: ",user,' --- ',"COM: ",computer)


    if computer_point>=3 or your_point>=3  or user=='خروج':
       gameroul=False     




if your_point>computer_point:
   print("کاربر برنده بازی شد ")   
elif your_point<computer_point:
   print("کامپیوتر برنده بازی شد ")    
else:
   print("شما خارج شدید برنده ای نداریم ")            

print("YOU: ",your_point,' - ')
print("COM: ",computer_point,' - ')
# Out:
# YOU:  خروج  ---  COM:  سنگ
# شما خارج شدید برنده ای نداریم
# YOU:  0  -
# COM:  0  -
